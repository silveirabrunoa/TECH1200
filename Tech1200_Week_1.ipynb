# %%
#Creating Variables

name = "Anna"
age = 25
grade = 'B'
rate = 5.79

print(name+" got grade "+grade+" in English ")

country = "Japan"
print("Tokyo is the capital city of" + country)

#how to create a value
value = input("enter a value")
print(value)

#replacing variable
variable = 100
variable = "This is the value"
print(variable)
# Out:
# Anna got grade B in English
# Tokyo is the capital city ofJapan
# enter a value 10
#  10
# This is the value

# %%
#Activity

numerator = 777
denominator = 0
result = numerator/denominator
print(result)

a = 0
b = 42.1
c = -912
d = "678"
e = 13513517
f = 0.0
g = -13.012
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-4123481833.py in <cell line: 0>()
#       1 numerator = 777
#       2 denominator = 0
# ----> 3 result = numerator/denominator
#       4 print(result)
#
# ZeroDivisionError: division by zero

# %%
#Calculations

print(69+5)
print(6-87)
print(6.2*100)
print(3/37)
# Out:
# 74
# -81
# 620.0
# 0.08108108108108109

# %%
#Exponents

# 2 to the 12th power, 2^12, or 4096
# or... 2 * 2 * 2 * 2 * 2 * 2 * 2 * 2 * 2 * 2 * 2 * 2
print(2 ** 12)

# 6 squared, 6^2, or 36
print(6 ** 2)

# 2 to the half power, 2^0.5, or 1.41
print(2 ** 0.5)
# Out:
# 4096
# 36
# 1.4142135623730951

# %%
#Concatenation

# prints "HelloWorld!"
a = "Hello"
b = "World!"
c = a + b
print(c)

# prints TypeError: can only concatenate str (not "int") to str
a = "Hello"
b = 5
print(a + b)
# Out:
# HelloWorld!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1838421996.py in <cell line: 0>()
#       8 a = "Hello"
#       9 b = 5
# ---> 10 print(a + b)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Modulo

# Prints 3
# 23 / 5 is 4, with a remainder of 3
print(23 % 5)

# Prints 1
# Important Note for "Modulo % 2"
# Returns "0 for even numbers" and "1 for odd numbers"
print(21 % 2)

# Prints 4
# 4 / 8 is 0, with a remainder of 4
print(4 % 8)
# Out:
# 3
# 1
# 4

# %%
# Plus equals

# prints 105
distance = 100
distance += 5 # same as distance = distance + 5
print(distance)

# prints add words to the String added
message = "add words to the String"
message += " added" # same as message = message + " added"
print(message)
# Out:
# 105
# add words to the String added

# %%
variable = """
I can
write
here
or here
:O
"""
print(variable)
# Out:
# I can
# write
# here
# or here
# :O
